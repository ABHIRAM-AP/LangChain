# %% [markdown]
# ### Data Ingestion

# %%
### Document Data Strcture


from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a simple Document",
    metadata={
        "source":"example.com",
        "pages":1,
        "author":"John",
        "date_created":"2025-01-02"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.com', 'pages': 1, 'author': 'John', 'date_created': '2025-01-02'}, page_content='This is a simple Document')

# %%
import os 
os.makedirs("data/text_files",exist_ok=True)

# %%
sample_texts={
"data/text_files/python_intro.txt":
"""
Python is.a high-level, interpreted programming language known for its.simplicity and readability.
Created .by Guido .van . Rossum and .first.released.in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
Easy to learn and use
Extensive standard library
Cross-platform compatibility
Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.

Python is widely used in web development, data science, artificial intelligence, and automatic"""
,
"data/text_files/machine_learning.txt":"""Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems.to learn and impr
from experience without being explicitly programmed. It.focuses .on .developing computer progran
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
"""
}
for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding='utf-8') as f:
        f.write(content)

print("Sample text files created")
# Out:
# Sample text files created

# %%
## Text Loader

from langchain_community.document_loaders import TextLoader 

loader=TextLoader('data/text_files/python_intro.txt',encoding='utf-8')
document=loader.load()
# Out:
# [Document(metadata={'source': 'data/text_files/python_intro.txt'}, page_content='\nPython is.a high-level, interpreted programming language known for its.simplicity and readability.\nCreated .by Guido .van . Rossum and .first.released.in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\nEasy to learn and use\nExtensive standard library\nCross-platform compatibility\nStrong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.\n\nPython is widely used in web development, data science, artificial intelligence, and automatic')]

# %%
## Directory Loader
from langchain_community.document_loaders import DirectoryLoader

dir_loaders = DirectoryLoader(
    path='data/text_files',
    glob='**/*.txt',
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)
docs=dir_loaders.load()
docs
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 116.66it/s]
# [Document(metadata={'source': 'data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems.to learn and impr\nfrom experience without being explicitly programmed. It.focuses .on .developing computer progran\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loaders=DirectoryLoader(
    'pdf/',
    glob='**/*.pdf',
    loader_cls=PyMuPDFLoader,
    show_progress=True
)
pdf_docs=dir_loaders.load()
pdf_docs
# type(pdf_docs[0])
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 65.52it/s]
# langchain_core.documents.base.Document
